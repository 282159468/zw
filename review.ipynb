# %% [markdown]
# - es
#     - weakmap实际应用
#         - sdfsdf
#         - sdfsdf
#
#             ```jsx
#             sdfsdfsdf
#             ```
#
#     - 迭代器、构造器，自定义迭代器
#     - 为什么需要箭头函数
#         - 清除函数的二义性：普通函数可以直接调用，也可以当构造函数
#     - flatMap应用filter+map
# - 基础
#     - 原型链
#
#         地
#
#         桂左
#
#     - floor、ceil、round
#         - floor向下，ceil向上，round
#     - 精度丢失
#
#         js中数字是以二进制双精度浮点数标准（IEEE 754）表示的，在转换成2进制时出现无限循环需要截断，所以出现精度丢失
#
#         ## api
#
#         Math.round() 函数返回一个数字四舍五入后最接近的整数。
#
#     - async、delay
#     - xhr、fetch区别
#     - get、post区别
#     - cros
#     - 事件循环
#     - 面向对象
#     - 设计模式
#     - reflect用处
#     - proxy、defineProperty区别
#     - promise
#         - all、allseeter区别
#     - this指向
#     - API
#         - Number
#             - epsilon 表示1和大于1的最小浮点数的差，可以理解成js中双精度浮点数理论误差，即小于这个误差在js中没有意义
#
#                 ```jsx
#                 function equal(x,y){
#
#                 return Math.abs(x-y) < Number.EPSILON
#                 }
#                 ```
#
#                 另外 Number.EPSILON的值等Math.pow(2, -52)，原因是
#
#                 ![Untitled](https://prod-files-secure.s3.us-west-2.amazonaws.com/b917b1ba-8d31-4f3d-b838-8e4a068a01f8/ee400f67-29d9-4651-a864-18a0005eebdd/Untitled.png)
#
# - ts
#     - 实现Pick、Omit
#     - 函数重载，js函数重载（jQuery）
#     - interface、type区别
#     - infer应用
# - react
#     - 应用题
#         - 调用setState后的更新过程
#     - 生命周期顺序
#     - react19更新内容
#     - react18类组件新的生命周期
#     - context优化
#     - useTransition
#     - useLayoutEffect实际差异
#     - suspense
# - 性能优化
#     - 资源
#         - 压缩包括、分割
#         - 按需加载、预加载、懒加载
#         - tree shaking
#     - 网络
#         - 强缓存、弱缓存
#         - 开启gzip等压缩传送
#         - dns预解析
# - 安全
#     - cros
#     - cps
#     - xss
#     - token
#     - 密码关键数据加解密
#     - refer
# - 网络
#     - https、httpx
#     - 三次握手、四次挥手
# - 常见题
#     - 对象深拷贝
#     - promise api实现
#     - 网页解析过程
# - css
#     - bfc
